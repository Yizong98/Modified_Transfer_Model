# %%
import numpy as np
import os
import time
from keras.preprocessing import image
from keras.layers import GlobalAveragePooling2D, Dense, Dropout,Activation,Flatten
from keras.layers import Input
from keras.models import Model
from keras.utils import np_utils
from sklearn.utils import shuffle
from sklearn.cross_validation import train_test_split
from keras.models import load_model
import audio_processor as ap

# %%
import glob

# %%
glob.glob("mini_test/*.mp3")
# Out:
# []

# %%
for i in glob.glob("data/mini_test/*.mp3"):
    print (i)
# Out:
# data/mini_test\Chopin - Andante spinato.mp3
# data/mini_test\Chopin - Ballade in A flat major op.47 no.3.mp3
# data/mini_test\Chopin - Ballade in F major op.38 No. 2.mp3
# data/mini_test\Chopin - Ballade in G minor, op.23 no.1.mp3
# data/mini_test\ChopinFuneralMarch.mp3
# data/mini_test\ChopinFuneralMarch2.mp3
# data/mini_test\ChopinHeroicPolonaise.mp3
# data/mini_test\ChopinMinuteWaltz.mp3
# data/mini_test\ChopinNocturneinGminor.mp3
# data/mini_test\ChopinPianoNocturninEbm.mp3
# data/mini_test\ChopinRomanticPiano.mp3
# data/mini_test\Kevin Kern - Because I Love You.mp3
# data/mini_test\Kevin Kern - dance.mp3
# data/mini_test\Kevin Kern - go the green.mp3
# data/mini_test\Kevin Kern - Le Jardin.mp3
# data/mini_test\Kevin Kern - secret.mp3
# data/mini_test\Kevin Kern - sun.mp3
# data/mini_test\Kevin Kern - The Touch Of Love.mp3
# data/mini_test\Kevin Kern - wave.mp3
# data/mini_test\Kevin Kern - We Should Waltz.mp3

# %%
melgrams = np.zeros((0, 1, 96, 1366))
for i in glob.glob("data/mini_test/*.mp3"):
    melgram = ap.compute_melgram(i)
    melgrams = np.concatenate((melgrams, melgram), axis=0)

# %%
melgrams = melgrams.transpose(0,2,3,1)

# %%
num_of_classes = 2
num_of_samples = 20
labels = np.ones((num_of_samples,),dtype='int64')
labels[0:10]=0
labels[10:]=1
names = ['Chopin','Other']
Y = np_utils.to_categorical(labels, num_of_classes)
x,y = shuffle(melgrams,Y, random_state=2)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 96, 1366, 1)       0
# _________________________________________________________________
# bn_0_freq (BatchNormalizatio (None, 96, 1366, 1)       384
# _________________________________________________________________
# conv1 (Conv2D)               (None, 96, 1366, 32)      320
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 96, 1366, 32)      128
# _________________________________________________________________
# elu_41 (ELU)                 (None, 96, 1366, 32)      0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 48, 341, 32)       0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 48, 341, 64)       18496
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 48, 341, 64)       256
# _________________________________________________________________
# elu_42 (ELU)                 (None, 48, 341, 64)       0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 24, 85, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 24, 85, 64)        36928
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 24, 85, 64)        256
# _________________________________________________________________
# elu_43 (ELU)                 (None, 24, 85, 64)        0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 12, 21, 64)        0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 12, 21, 64)        36928
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 12, 21, 64)        256
# _________________________________________________________________
# elu_44 (ELU)                 (None, 12, 21, 64)        0
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 4, 4, 64)          0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 4, 4, 32)          18464
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 4, 4, 32)          128
# _________________________________________________________________
# elu_45 (ELU)                 (None, 4, 4, 32)          0
# =================================================================
# Total params: 114,194
# Trainable params: 113,490
# Non-trainable params: 704
# _________________________________________________________________
# c:\users\yizong\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py:975: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'

# %%
model.predict(melgrams)
# Out:
# array([[[[-9.82776999e-01, -8.84147406e-01, -3.58051419e-01, ...,
#            4.97467947e+00, -9.99651968e-01, -4.73535120e-01],
#          [-9.22749877e-01, -7.74543524e-01,  2.78939462e+00, ...,
#            2.93812919e+00, -9.99841154e-01, -7.81509757e-01],
#          [-9.45404410e-01, -1.17278636e-01,  3.16448879e+00, ...,
#            3.73455644e+00, -9.99082565e-01, -7.58592904e-01],
#          [ 2.50736296e-01,  1.13757622e+00,  2.60495186e+00, ...,
#            7.02218533e-01, -9.94976282e-01, -2.84664631e-01]],
#
#         [[ 6.55685723e-01, -9.89956737e-01,  2.00240397e+00, ...,
#            2.56506753e+00, -9.99875605e-01,  2.20925331e+00],
#          [ 4.39056492e+00, -9.92891610e-01,  4.26094961e+00, ...,
#            3.11804390e+00, -9.99584138e-01,  2.45156217e+00],
#          [ 3.31565094e+00, -9.11100268e-01,  4.15635443e+00, ...,
#            2.35637307e+00, -9.99256432e-01,  2.79120755e+00],
#          [ 4.07795000e+00, -4.15033102e-03,  2.82640696e+00, ...,
#            2.27714086e+00, -9.95070338e-01,  2.99029160e+00]],
#
#         [[ 7.65850842e-01, -9.75981295e-01,  2.50053072e+00, ...,
#            1.29520035e+00, -9.99538779e-01,  3.01005387e+00],
#          [ 4.06070900e+00, -8.62376094e-01,  5.27274132e+00, ...,
#            1.41674793e+00, -9.99659121e-01,  3.48468471e+00],
#          [ 2.97618961e+00, -3.57460856e-01,  4.20895529e+00, ...,
#            1.32590222e+00, -9.99674797e-01,  3.43858004e+00],
#          [ 4.11415768e+00,  1.67220020e+00,  3.48969197e+00, ...,
#            1.06662798e+00, -9.98062193e-01,  3.17494893e+00]],
#
#         [[ 3.71801186e+00, -9.96921957e-01,  1.60913455e+00, ...,
#           -5.54617763e-01, -8.55102539e-01,  3.10983014e+00],
#          [ 7.46579218e+00, -9.74313319e-01,  1.90425885e+00, ...,
#           -7.40446746e-01, -6.16983294e-01,  4.68005800e+00],
#          [ 6.13948822e+00, -9.43672538e-01,  2.35637283e+00, ...,
#           -4.08258617e-01, -8.00929606e-01,  4.45463991e+00],
#            2.03030601e-01, -4.15947914e-01, -5.36358714e-01],
#          [ 1.80444932e+00, -3.53713632e-02, -4.29035723e-01, ...,
#            2.70208359e-01, -5.20328283e-01, -4.01139975e-01]]],
#
#
#        [[[-3.87608886e-01, -5.50980926e-01, -5.27670383e-02, ...,
#            5.43037713e-01, -8.74183953e-01,  2.07735077e-01],
#          [-6.93202794e-01, -7.25620627e-01,  8.88082922e-01, ...,
#            5.82342386e-01, -9.54542696e-01, -2.56352186e-01],
#          [ 5.17617390e-02, -4.69280958e-01,  6.18934751e-01, ...,
#            2.36384332e-01, -9.88008320e-01, -1.11849785e-01],
#          [ 1.86754179e+00, -7.63020754e-01,  6.25620663e-01, ...,
#           -3.82519603e-01, -9.82568622e-01, -5.89371443e-01]],
#
#         [[ 2.43841863e+00, -8.01648974e-01,  8.32372427e-01, ...,
#           -2.05051661e-01, -5.42405009e-01,  9.45363417e-02],
#          [ 3.17511940e+00, -7.11441815e-01,  4.73945975e-01, ...,
#           -6.84926569e-01, -5.50916076e-01,  6.77336216e-01],
#          [ 4.64917994e+00, -9.61986005e-01,  1.19536150e+00, ...,
#           -6.46759152e-01, -9.57127869e-01,  5.28528273e-01],
#          [ 5.72341776e+00,  5.91554224e-01, -5.25369644e-01, ...,
#           -3.21168661e-01, -8.99303079e-01,  5.35899639e-01]],
#
#         [[ 1.00975561e+00, -3.99803221e-01,  3.31645578e-01, ...,
#           -1.65782452e-01, -3.88523281e-01,  5.53364992e-01],
#          [ 2.23121786e+00, -5.26643276e-01,  8.21718574e-01, ...,
#           -2.25210547e-01, -8.33125114e-02,  1.00473285e+00],
#          [ 2.91260076e+00, -6.12685561e-01,  1.29101670e+00, ...,
#           -3.05619299e-01,  1.26183137e-01,  1.18244350e+00],
#          [ 3.37826109e+00, -3.80488575e-01,  3.33731383e-01, ...,
#           -1.09090090e-01, -6.25617266e-01,  1.35371268e+00]],
#
#         [[ 7.55896509e-01, -5.38668394e-01,  3.55439782e-01, ...,
#           -1.18858218e-01,  1.20145001e-01,  1.03558469e+00],
#          [ 1.10392439e+00, -5.06084025e-01,  6.69428945e-01, ...,
#           -4.22791421e-01,  6.69680238e-01,  1.17762434e+00],
#          [ 9.22556758e-01, -4.31146860e-01,  8.80088210e-01, ...,
#           -2.96773911e-01,  4.13048357e-01,  1.42103696e+00],
#          [ 5.11790931e-01, -2.16920376e-02,  7.15831041e-01, ...,
#           -9.85137224e-02,  1.84218585e-01,  1.21906173e+00]]]],
#       dtype=float32)

# %%
trans_model = load_model('transfer_model.h5')
# Out:
# c:\users\yizong\appdata\local\programs\python\python36\lib\site-packages\keras\models.py:282: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
trans_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 96, 1366, 1)       0
# _________________________________________________________________
# bn_0_freq (BatchNormalizatio (None, 96, 1366, 1)       384
# _________________________________________________________________
# conv1 (Conv2D)               (None, 96, 1366, 32)      320
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 96, 1366, 32)      128
# _________________________________________________________________
# elu_46 (ELU)                 (None, 96, 1366, 32)      0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 48, 341, 32)       0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 48, 341, 64)       18496
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 48, 341, 64)       256
# _________________________________________________________________
# elu_47 (ELU)                 (None, 48, 341, 64)       0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 24, 85, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 24, 85, 64)        36928
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 24, 85, 64)        256
# _________________________________________________________________
# elu_48 (ELU)                 (None, 24, 85, 64)        0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 12, 21, 64)        0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 12, 21, 64)        36928
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 12, 21, 64)        256
# _________________________________________________________________
# elu_49 (ELU)                 (None, 12, 21, 64)        0
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 4, 4, 64)          0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 4, 4, 32)          18464
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 4, 4, 32)          128
# _________________________________________________________________
# elu_50 (ELU)                 (None, 4, 4, 32)          0
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 50)                1650
# =================================================================
# Total params: 114,194
# Trainable params: 113,490
# Non-trainable params: 704
# _________________________________________________________________

# %%
from keras import backend as K

# %%
num_of_classes = 2
num_of_samples = 20
labels = np.ones((num_of_samples,),dtype='int64')
labels[0:10]=0
labels[10:]=1
names = ['Chopin','Other']
Y = np_utils.to_categorical(labels, num_of_classes)
x,y = shuffle(melgrams,Y, random_state=2)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
last_layear = trans_model.get_layer('pool3').output
flat = Flatten(name='flatten')(last_layear)
out = Dense(num_of_classes, activation='softmax', name='output_layer')(flat)
custom_model = Model(inputs=melgram_input,outputs= out)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-109-1c3000502502> in <module>()
#       2 x = Flatten(name='flatten')(last_layear)
#       3 out = Dense(num_of_classes, activation='softmax', name='output_layer')(x)
# ----> 4 custom_model = Model(inputs=melgram_input,outputs= c)
#
# c:\users\yizong\appdata\local\programs\python\python36\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# c:\users\yizong\appdata\local\programs\python\python36\lib\site-packages\keras\engine\topology.py in __init__(self, inputs, outputs, name)
#    1809                                 'The following previous layers '
#    1810                                 'were accessed without issue: ' +
# -> 1811                                 str(layers_with_complete_input))
#    1812                     for x in node.output_tensors:
#    1813                         computable_tensors.append(x)
#
# RuntimeError: Graph disconnected: cannot obtain value for tensor Tensor("input_10:0", shape=(?, 96, 1366, 1), dtype=float32) at layer "input_10". The following previous layers were accessed without issue: []

# %%
trans_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 96, 1366, 1)       0
# _________________________________________________________________
# bn_0_freq (BatchNormalizatio (None, 96, 1366, 1)       384
# _________________________________________________________________
# conv1 (Conv2D)               (None, 96, 1366, 32)      320
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 96, 1366, 32)      128
# _________________________________________________________________
# elu_46 (ELU)                 (None, 96, 1366, 32)      0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 48, 341, 32)       0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 48, 341, 64)       18496
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 48, 341, 64)       256
# _________________________________________________________________
# elu_47 (ELU)                 (None, 48, 341, 64)       0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 24, 85, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 24, 85, 64)        36928
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 24, 85, 64)        256
# _________________________________________________________________
# elu_48 (ELU)                 (None, 24, 85, 64)        0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 12, 21, 64)        0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 12, 21, 64)        36928
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 12, 21, 64)        256
# _________________________________________________________________
# elu_49 (ELU)                 (None, 12, 21, 64)        0
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 4, 4, 64)          0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 4, 4, 32)          18464
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 4, 4, 32)          128
# _________________________________________________________________
# elu_50 (ELU)                 (None, 4, 4, 32)          0
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 50)                1650
# =================================================================
# Total params: 114,194
# Trainable params: 113,490
# Non-trainable params: 704
# _________________________________________________________________

# %%
melgrams_input = Input(shape=(96,1366,1))

# %%
melgrams_input
# Out:
# <tf.Tensor 'input_11:0' shape=(?, 96, 1366, 1) dtype=float32>

# %%
last_layear = trans_model.get_layer('pool5').output
flat = Flatten(name='flatten')(last_layear)
out = Dense(num_of_classes, activation='softmax', name='output_layer')(flat)
custom_model = Model(melgrams_input,outputs= out)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-136-86d2c27f28b9> in <module>()
#       2 flat = Flatten(name='flatten')(last_layear)
#       3 out = Dense(num_of_classes, activation='softmax', name='output_layer')(flat)
# ----> 4 custom_model = Model(melgrams_input,outputs= out)
#
# c:\users\yizong\appdata\local\programs\python\python36\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# c:\users\yizong\appdata\local\programs\python\python36\lib\site-packages\keras\engine\topology.py in __init__(self, inputs, outputs, name)
#    1809                                 'The following previous layers '
#    1810                                 'were accessed without issue: ' +
# -> 1811                                 str(layers_with_complete_input))
#    1812                     for x in node.output_tensors:
#    1813                         computable_tensors.append(x)
#
# RuntimeError: Graph disconnected: cannot obtain value for tensor Tensor("input_10:0", shape=(?, 96, 1366, 1), dtype=float32) at layer "input_10". The following previous layers were accessed without issue: []
